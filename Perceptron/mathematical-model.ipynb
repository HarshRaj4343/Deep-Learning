# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions

# %%
df = pd.read_csv("/Users/harshraj/Desktop/Deep-Learning/Datasets/placement.csv")

# %%
sns.scatterplot(data=df, x="cgpa", y="resume_score", hue="placed")
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1] 
def step(x:float)->int:
    return 1 if x>=0 else 0

# %%
def Perceptron(X,y,learning_rate=0.01, epochs=1000):
    X = np.insert(X,0,1,axis=1)
    weights = np.ones(X.shape[1])
    for i in range(epochs):
        j = np.random.randint(0,X.shape[1]+1)
        y_hat = step(np.dot(weights,X[j]))
        weights = weights + learning_rate*(y[j]-y_hat)*X[j]
    return weights[0],weights[1:]

# %%
intercept_,coef_ = (Perceptron(X,y))

# %%
m = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])

# %%
final_eq = m*X+b
